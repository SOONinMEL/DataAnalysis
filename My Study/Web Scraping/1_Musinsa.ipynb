# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
url='https://www.musinsa.com/category/001001?d_cat_cd=001001&brand=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page=1&display_cnt=90&sale_goods=&group_sale=&kids=N&ex_soldout=&color=&price1=&price2=&exclusive_yn=&shoeSizeOption=&tags=&campaign_id=&timesale_yn=&q=&includeKeywords=&measure='
headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}

# %%
res=requests.get(url,headers=headers)
res.raise_for_status
# Out:
# <bound method Response.raise_for_status of <Response [200]>>

# %%
soup=BeautifulSoup(res.text,'lxml')

# %%
items=soup.find_all('div',attrs={'class':re.compile('^li_inner')})

# %%
# 쿠폰할인제외

for item in items:
    discount=item.find('p',attrs={'class':'mu-icon mu-icon-coupon'})
    
    if discount:
        print('쿠폰할인 제외합니다.')
        continue
    
    name=item.find('p',attrs={'class':'list_info'})
    name=name.a.get_text()
    
    price=item.find('p',attrs={'class':'price'}).get_text()
    
    likes_count=item.find('p',attrs={'class':'txt_cnt_link'})
    
    if likes_count:
        likes_count=rate_count.get_text()
        likes_count=rate_count[2:7]
        print('좋아요수',likes_count)
    
  
        
    rates=item.find('span',attrs={'class':'count'}).get_text()
    
    print(name, price, likes_count, rates)
# Out:
# 쿠폰할인 제외합니다.
#
#
#
#
#
#                                     [990원 이벤트] 쿨탠다드 릴렉스 핏 크루 넥 반팔 티셔츠 [블랙]
#
# 16,900원 990원
#                              None 3,715
#
#
#
#
#
#                                     [990원 이벤트] 쿨탠다드 릴렉스 핏 크루 넥 반팔 티셔츠 [화이트]
#
# 16,900원 990원
#                              None 3,771
#
#
#
#
#
#                                     릴렉스 핏 크루 넥 반팔 티셔츠 [화이트]
#
#                                  11,900원
#                              None 63,271
#
#
#
#
#
#                                     레이어드 크루 넥 반팔 티셔츠_일반 기장 [화이트]
#
#                                  13,900원
#                              None 12,928
#
# 5/18 배송
#
#                                     미시간 울버린 피그먼트  반팔티 블랙차콜
#
# 39,000원 27,900원
#                              None 11,066
#
#
#
#
#
#                                     쿨코튼 2-PACK 베츠 기본 반팔 티셔츠 블랙/화이트
#
# 49,000원 31,850원
#                              None 5,884
#
#
#
#
#
# ...
